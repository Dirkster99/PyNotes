# %% [markdown]
# # Get Data fom Local Storage

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
sourcePath = "/gdrive/MyDrive/GermanDataSets/CourtRulings/100_SentenceSplits/data/V1/"
# !ls {sourcePath.replace(' ', '\ ')} -lha
# Out:
# total 51M
# -rw------- 1 root root 2.9M Aug 21 21:26 100_2019-02-19_oldp_cases_textout_SentenceSplitter.csv
# -rw------- 1 root root 2.9M Aug 22 16:06 100_array_2019-02-19_oldp_cases_textout.json
# -rw------- 1 root root  21M Aug 21 21:39 1k_2019-02-19_oldp_cases_textout_SentenceSplitter.csv
# -rw------- 1 root root  25M Aug 22 16:06 1k_array_2019-02-19_oldp_cases_textout.json
# drwx------ 2 root root 4.0K Aug 22 20:37 1k_SentenceDetectorDLModel
# -rw------- 1 root root 3.2K Aug 21 21:22 abbreviations_relevant_dictionary.txt
# -rw------- 1 root root 1.6K Aug 22 15:18 abbreviations_relevant_dictionary_wo_periods.txt

# %% [markdown]
# # Setup Spark

# %%
# This is only to setup PySpark and Spark NLP on Colab
# !wget http://setup.johnsnowlabs.com/colab.sh -O - | bash
# Out:
# --2021-08-22 20:38:26--  http://setup.johnsnowlabs.com/colab.sh
# Resolving setup.johnsnowlabs.com (setup.johnsnowlabs.com)... 51.158.130.125
# Connecting to setup.johnsnowlabs.com (setup.johnsnowlabs.com)|51.158.130.125|:80... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh [following]
# --2021-08-22 20:38:26--  https://raw.githubusercontent.com/JohnSnowLabs/spark-nlp/master/scripts/colab_setup.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1608 (1.6K) [text/plain]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   1.57K  --.-KB/s    in 0s
#
# 2021-08-22 20:38:27 (47.4 MB/s) - written to stdout [1608/1608]
#
# setup Colab for PySpark 3.1.2 and Spark NLP 3.2.1
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,294 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [543 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,424 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,792 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,730 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,199 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [575 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [34.4 kB]
# Get:24 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [917 kB]
# Fetched 12.8 MB in 4s (3,468 kB/s)
# Reading package lists... Done
#      |████████████████████████████████| 212.4 MB 64 kB/s
#      |████████████████████████████████| 116 kB 23.6 MB/s
#      |████████████████████████████████| 198 kB 77.8 MB/s
#   Building wheel for pyspark (setup.py) ... done

# %%
from pyspark.ml import PipelineModel
from sparknlp.annotator import *
from sparknlp.base import *
import sparknlp

spark = sparknlp.start(gpu=True)

print("Spark version:", spark.version)
print("Spark NLP version:", sparknlp.version())
# Out:
# Spark version: 3.1.2
# Spark NLP version: 3.2.1

# %% [markdown]
# # Read Training Data & Train Sentences Detector Model to recognize Abbreviations

# %%
#inputFile = '100_2019-02-19_oldp_cases_textout_SentenceSplitter.csv'
inputFile = '1k_2019-02-19_oldp_cases_textout_SentenceSplitter.csv'

# %%
trainingDF = spark.read.format('com.databricks.spark.csv')                                \
           .options( delimiter='|', header='true', inferschema='true', encoding="utf-8")  \
           .load(sourcePath + inputFile)                                                  \
           .where('ContainsAbbr = 1')                                                     \
           .select('Text')                                                                  \
           .withColumnRenamed('Text', 'text')

trainingDF.printSchema()
trainingDF.count()
# Out:
# root
#  |-- text: string (nullable = true)
# 44721

# %%
def readFile(fileName):
  fileObj = open(fileName, "r") #opens the file in read mode
  words = fileObj.read().splitlines() #puts the file into an array
  fileObj.close()
  return words

abbrevitions  = readFile(sourcePath + 'abbreviations_relevant_dictionary.txt')
print (abbrevitions)
# Out:
# ['-drs.', '1. zivilkammer', '10. zivilkammer', '11. zivilkammer', '12. zivilkammer', '13. zivilkammer', '14. zivilkammer', '15. zivilkammer', '16. zivilkammer', '17. zivilkammer', '18. zivilkammer', '19. zivilkammer', '2.\xa0zivilkammer', '20. zivilkammer', '21. zivilkammer', '22. zivilkammer', '23. zivilkammer', '24. zivilkammer', '25. zivilkammer', '26. zivilkammer', '27. zivilkammer', '28. zivilkammer', '29. zivilkammer', '3. zivilkammer', '30. zivilkammer', '31. zivilkammer', '32. zivilkammer', '33. zivilkammer', '34. zivilkammer', '35. zivilkammer', '36. zivilkammer', '37. zivilkammer', '38. zivilkammer', '39. zivilkammer', '4. zivilkammer', '5. zivilkammer', '6. zivilkammer', '7. zivilkammer', '8. zivilkammer', '9  . zivilkammer', '9. zivilkammer', 'a.', 'aao.', 'abbldg.', 'abdr.', 'abl.', 'abs.', 'abt.', 'akad.', 'akt.', 'alt.', 'amtl.', 'anh.', 'anl.', 'anm.', 'art. 1', 'art. 2', 'art. 3', 'art. 4', 'art. 5', 'art. 6', 'art. 7', 'art. 8', 'art. 9', 'art. i', 'art. v', 'aufl.', 'auﬂ.', 'az.', 'b.', 'bac.', 'barbarastr.', 'bb.', 'bd.', 'bds.', 'befr.', 'begr.', 'bek.', 'bekl.', 'ber.', 'besch.', 'beschl.', 'betr.', 'bgbl.', 'bk.', 'bl.', 'br-drs.', 'bros.', 'bsp.', 'bspw.', 'bstbl.', 'bt-drs.', 'btdrs.', 'btdrucks.', 'buchst.', 'bverwg.', 'bzgl.', 'bzw.', 'bü.-drs.', 'c.', 'ca.', 'cc.', 'd.', 'd. h.', 'd.h.', 'dd.', 'ders.', 'dez.', 'dipl.', 'diss.', 'doknr.', 'dr.', 'dres.', 'drs.', 'drug.', 'dr\xa0\xa0h.', 'dt.', 'dvbl.', 'e.', 'ed.', 'einschl.', 'emrk.', 'erg.', 'erl.', 'et. al.', 'evtl.', 'ex.', 'exkl.', 'f.', 'fa.', 'febr.', 'ff.', 'fi.', 'fig.', 'flnr.', 'flurstück-nr.', 'fn.', 'fr.', 'fs.', 'g.', 'gbl.', 'ge.', 'geb.', 'gebr.', 'gem.', 'gesbl.', 'ggf.', 'ggfls.', 'ggfs.', 'ggü.', 'gr.', 'grds.', 'gv. nrw.', 'gvbl.', 'gz.', 'h.', 'ha.', 'hamb.', 'hauptstr.', 'hdb.', 'herrenstr.', 'hess.', 'hmbgvbl.', 'hmbjvbl.', 'ho.', 'hr.', 'Hrsg.', 'hs.', 'hsog.', 'höh.', 'i.', 'i. s.d.', 'i.h.v.', 'i.s.d.', 'i.s.v.', 'i.v.m.', 'i.\xa0s.v.', 'i.ü.', 'ihv.', 'ii.', 'iii.', 'iii\xa0rn.', 'imabl.', 'inabl.', 'inart.', 'inc.', 'incl.', 'ing.', 'inkl.', 'insb.', 'insbes.', 'insg.', 'insges.', 'int.', 'intra-nr.', 'irisl].', 'isd.', 'iv.', 'ivm.', 'ix.', 'j.', 'jan.', 'jew.', 'jmbl.', 'juris-rdnr.', 'juris-rnr.', 'k.', 'kammerbeschl.', 'kap.', 'karlstr.', 'kat.', 'kft.', 'kirchstr.', 'kostenverzeichnis-nr.', 'kp.', 'krit.', 'krit. anm.', 'ktbzw.', 'kv-nr.', 'kw.', 'l.', 'lansv.', 'lfd.', 'lfg.', 'li.', 'lit.', 'ls.', 'lt-drs.', 'lt-drucks.', 'lt.', 'ltd.', 'm.', 'm. ü.', 'maternusstr.', 'mbl.', 'med.', 'mill.', 'mind.', 'mio.', 'mit-nr.', 'mrd.', 'mwst.', 'n.', 'n.f.', 'nachw.', 'nds.', 'ndsvbl.', 'neustadt/wstr.', 'no.', 'nr.', 'nrn.', 'nrw-drs.', 'nw.', 'nwvbl.', 'o.', 'o. e. i.', 'oct.', 'okt.', 'ovg-az.', 'p.', 'pkt.', 'pos.', 'pp.', 'prof.', 'prog.', 'prot. v.', 'q.', 'r.', 'randnr.', 'rd.', 'rderl.', 'rdn.', 'rdnr.', 'rdnrn.', 're.', 'rechnung-nr.', 'reg.', 'rev.', 'rgbl.', 'rn .', 'rn.', 'rndnr.', 'rndr.', 'rnr.', 'rnrn.', 'rpfl.', 'rpsr.', 'rrn.', 'rs.', 'rspr.', 'rthon.', 'rz.', 's.', 'sch.', 'senatsbeschl.', 'sep.', 'sept.', 'sgl.', 'slg.', 'soc.', 'sp.', 'spol.', 'st.', 'st.-georg-str.', 'std.', 'str.', 'strspr.', 'sächs.', 't.', 'thür.', 'tlw.', 'tt.', 'tz.', 'u.', 'u. a.', 'u.a.', 'ua.', 'uabs.', 'undabl.', 'undprof.', 'unterabs.', 'unterbuchst.', 'urnr.', 'urt.', 'usf.', 'ust.', 'usw.', 'uä.', 'v.', 'vergl.', 'vers.', 'vf.', 'vgl.', 'vi.', 'vii.', 'viii.', 'vol.', 'vom.', 'vorb.', 'vorbem.', 'vs.', 'vwvfg/art.', 'w.', 'wilhelmstr.', 'www.', 'www. f..de', 'www.a…de', 'www.b-apotheke.de', 'www.bestattungen.', 'www.bestattungen.de', 'www.bundesarbeitsgericht.de.78\\n*', 'www.bundesarbeitsgericht.de.82\\n*', 'www.bundesverfassungsgericht.de', 'www.bverfg.de', 'www.bverwg.de', 'www.europaeischer-referenzrahmen.de/englisch-sprachzertifikate.php', 'www.europaeischer-referenzrahmen.de/franzoesisch-sprachzertifikate.php', 'www.google.com', 'www.google.de', 'www.hhu.de', 'www.klepper.net', 'www.nrwe.de', 'www.refworld.org/cases,fr ...

# %%
logPath = './logs/'
# !mkdir logPath

# %%
# !rm -r -f {logPath + '*.*'}

# %% [markdown]
# See [SentenceDetectorDLApproach API](https://nlp.johnsnowlabs.com/api/python/reference/autosummary/sparknlp.annotator.SentenceDetectorDLApproach.html) for more details.

# %%
documentAssembler = DocumentAssembler() \
    .setInputCol("text")                \
    .setOutputCol("document")

sentenceDetector = SentenceDetectorDLApproach() \
    .setInputCols(["document"])                 \
    .setOutputCol("sentences")                  \
    .setEpochsNumber(3)                         \
    .setValidationSplit(.2)                     \
    .setOutputLogsPath(logPath)                 \
    .setImpossiblePenultimates(abbrevitions)

pipeline = Pipeline().setStages([documentAssembler, sentenceDetector])

# %%
# %%time
model = pipeline.fit(trainingDF)
# Out:
# CPU times: user 382 ms, sys: 57.2 ms, total: 439 ms
# Wall time: 1min 32s

# %%
ls {logPath} -lha
# Out:
# total 12K
# drwxr-xr-x 2 root root 4.0K Aug 22 20:41 ./
# drwxr-xr-x 1 root root 4.0K Aug 22 20:41 ../
# -rw-r--r-- 1 root root  261 Aug 22 20:42 sentence_detector_dl.log

# %%
# !head -n 50 {logPath + 'sentence_detector_dl.log'}
# Out:
# Training 3 epochs
# Epoch 1/3	47.26s	Loss: 892.9996	ACC: 0.9477721	Validation ACC: 0.97440016
# Epoch 2/3	15.54s	Loss: 440.00717	ACC: 0.97704667	Validation ACC: 0.9774851
# Epoch 3/3	14.89s	Loss: 377.01813	ACC: 0.9806159	Validation ACC: 0.9803536
# Training completed.

# %%
testDF = spark.createDataFrame(
    [
        (1, 'Ich teste mal eine Referenz mit Auflage gem. Hüßtege in Thomas/Putzo ZPO 39. Aufl. § 72a GVGR. Eigentlich sollte das doch funktionieren? Oder nicht?'), # create your data here, be consistent in the types.
        (2, 'Bin mal gespannt ob das i.S.d. Erfinders ist. Der Erfinder hatte eventuell etwas ganz anderes im Sinn?'),
    ],
    ['id', 'text'] # add your columns label here
)

testDF.printSchema()
testDF.show()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- text: string (nullable = true)
#
# +---+--------------------+
# | id|                text|
# +---+--------------------+
# |  1|Ich teste mal ein...|
# |  2|Bin mal gespannt ...|
# +---+--------------------+

# %%
model.transform(testDF).select('sentences').show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |sentences                                                                                                                                                                                                                                                                            |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{document, 0, 93, Ich teste mal eine Referenz mit Auflage gem. Hüßtege in Thomas/Putzo ZPO 39. Aufl. § 72a GVGR., {sentence -> 0}, []}, {document, 95, 135, Eigentlich sollte das doch funktionieren?, {sentence -> 1}, []}, {document, 137, 147, Oder nicht?, {sentence -> 2}, []}]|
# |[{document, 0, 44, Bin mal gespannt ob das i.S.d. Erfinders ist., {sentence -> 0}, []}, {document, 46, 101, Der Erfinder hatte eventuell etwas ganz anderes im Sinn?, {sentence -> 1}, []}]                                                                                          |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
print (type(model))
print (type(model.stages[0]))
print (type(model.stages[1]))
# Out:
# <class 'pyspark.ml.pipeline.PipelineModel'>
# <class 'sparknlp.base.DocumentAssembler'>
# <class 'sparknlp.annotator.SentenceDetectorDLModel'>

# %%
#Save and re-load the Sentence Detector model later as part of a different pipeline if you are happy with it.
model.stages[1].write().overwrite().save(sourcePath + '1k_SentenceDetectorDLModel')
